# %%
# Import our dependencies
import pandas as pd

# %%
#  Import and read the charity_data.csv.
df = pd.read_csv("Resources/dataset.csv", index_col=0)
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %%
# If popularity is 50 or more, hit column = 1; else 0
df.loc[df['popularity'] >= 50, 'hit'] = 1
df.loc[df['popularity'] < 50, 'hit'] = 0
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  ...  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1  ...     0       0.1430        0.0322
# 1         0.420  0.1660    1  ...     1       0.0763        0.9240
# 2         0.438  0.3590    0  ...     1       0.0557        0.2100
# 3         0.266  0.0596    0  ...     1       0.0363        0.9050
# 4         0.618  0.4430    2  ...     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre  \
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
#    hit
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0
#
# [5 rows x 21 columns]

# %%
# Check number of genres
genre_count = df.track_genre.value_counts()
genre_count
# Out:
# acoustic             1000
# punk-rock            1000
# progressive-house    1000
# power-pop            1000
# pop                  1000
#                      ...
# folk                 1000
# emo                  1000
# electronic           1000
# electro              1000
# world-music          1000
# Name: track_genre, Length: 114, dtype: int64

# %%
pd.set_option('display.max_rows', 1000)

# %%
genre_count
# Out:
# acoustic             1000
# punk-rock            1000
# progressive-house    1000
# power-pop            1000
# pop                  1000
# pop-film             1000
# piano                1000
# party                1000
# pagode               1000
# opera                1000
# new-age              1000
# mpb                  1000
# minimal-techno       1000
# metalcore            1000
# metal                1000
# mandopop             1000
# malay                1000
# latino               1000
# latin                1000
# kids                 1000
# k-pop                1000
# jazz                 1000
# j-rock               1000
# j-pop                1000
# j-idol               1000
# j-dance              1000
# iranian              1000
# psych-rock           1000
# punk                 1000
# afrobeat             1000
# r-n-b                1000
# turkish              1000
# trip-hop             1000
# trance               1000
# techno               1000
# tango                1000
# synth-pop            1000
# swedish              1000
# study                1000
# spanish              1000
# soul                 1000
# songwriter           1000
# sleep                1000
# ska                  1000
# singer-songwriter    1000
# show-tunes           1000
# sertanejo            1000
# samba                1000
# salsa                1000
# sad                  1000
# romance              1000
# rockabilly           1000
# rock                 1000
# rock-n-roll          1000
# reggaeton            1000
# reggae               1000
# industrial           1000
# indie                1000
# indie-pop            1000
# indian               1000
# disney               1000
# disco                1000
# detroit-techno       1000
# deep-house           1000
# death-metal          1000
# dancehall            1000
# dance                1000
# country              1000
# comedy               1000
# club                 1000
# classical            1000
# chill                1000
# children             1000
# chicago-house        1000
# cantopop             1000
# british              1000
# breakbeat            1000
# brazil               1000
# blues                1000
# bluegrass            1000
# black-metal          1000
# anime                1000
# ambient              1000
# alternative          1000
# alt-rock             1000
# drum-and-bass        1000
# dub                  1000
# dubstep              1000
# groove               1000
# idm                  1000
# house                1000
# honky-tonk           1000
# hip-hop              1000
# heavy-metal          1000
# hardstyle            1000
# hardcore             1000
# hard-rock            1000
# happy                1000
# guitar               1000
# grunge               1000
# grindcore            1000
# edm                  1000
# goth                 1000
# gospel               1000
# german               1000
# garage               1000
# funk                 1000
# french               1000
# forro                1000
# folk                 1000
# emo                  1000
# electronic           1000
# electro              1000
# world-music          1000
# Name: track_genre, dtype: int64

# %%
# Drops non-popular genres
df2 = df[~(df.track_genre.isin(['acoustic', 'party', 'songwriter', 'sleep', 'singer-songwriter','sad','romance','rockability',
                               'industrial','comedy','chill','breakbeat','drum-and-bass','honky-tonk',
                               'happy','guitar','grunge','gospel','garage']))]

# %%
# Check new number of genres
genre_count2 = df2.track_genre.value_counts()
genre_count2
# Out:
# afrobeat             1000
# alt-rock             1000
# progressive-house    1000
# power-pop            1000
# pop                  1000
# pop-film             1000
# piano                1000
# pagode               1000
# opera                1000
# new-age              1000
# mpb                  1000
# minimal-techno       1000
# metalcore            1000
# metal                1000
# mandopop             1000
# malay                1000
# latino               1000
# latin                1000
# kids                 1000
# k-pop                1000
# jazz                 1000
# j-rock               1000
# j-pop                1000
# psych-rock           1000
# punk-rock            1000
# punk                 1000
# soul                 1000
# turkish              1000
# trip-hop             1000
# trance               1000
# techno               1000
# tango                1000
# synth-pop            1000
# swedish              1000
# study                1000
# spanish              1000
# ska                  1000
# r-n-b                1000
# show-tunes           1000
# sertanejo            1000
# samba                1000
# salsa                1000
# rockabilly           1000
# rock                 1000
# rock-n-roll          1000
# reggaeton            1000
# reggae               1000
# j-idol               1000
# j-dance              1000
# iranian              1000
# children             1000
# disco                1000
# detroit-techno       1000
# deep-house           1000
# death-metal          1000
# dancehall            1000
# dance                1000
# country              1000
# club                 1000
# classical            1000
# chicago-house        1000
# dub                  1000
# cantopop             1000
# british              1000
# brazil               1000
# blues                1000
# bluegrass            1000
# black-metal          1000
# anime                1000
# ambient              1000
# alternative          1000
# disney               1000
# dubstep              1000
# indie                1000
# groove               1000
# indie-pop            1000
# indian               1000
# idm                  1000
# house                1000
# hip-hop              1000
# heavy-metal          1000
# hardstyle            1000
# hardcore             1000
# hard-rock            1000
# grindcore            1000
# edm                  1000
# goth                 1000
# german               1000
# funk                 1000
# french               1000
# forro                1000
# folk                 1000
# emo                  1000
# electronic           1000
# electro              1000
# world-music          1000
# Name: track_genre, dtype: int64

# %%
df2.loc[(df['track_genre'] == 'pagode') | (df['track_genre'] == 'latino') |(df['track_genre'] == 'mpb') 
        | (df['track_genre'] == 'latin') | (df['track_genre'] == 'samba')| (df['track_genre'] == 'salsa'), 'genre2'] = 'Latin'
df2.loc[(df['track_genre'] == 'show-tunes') | (df['track_genre'] == 'anime'), 'genre2'] = 'Cinema'
df2.loc[(df['track_genre'] == 'jazz') | (df['track_genre'] == 'blues'), 'genre2'] = 'Jazz_Blues'
df2.loc[(df['track_genre'] == 'sertanejo') | (df['track_genre'] == 'country') 
        | (df['track_genre'] == 'bluegrass') | (df['track_genre'] == 'folk'), 'genre2'] = 'Country'
df2.loc[(df['track_genre'] == 'progressive-house') | (df['track_genre'] == 'minimal-techno') |(df['track_genre'] == 'j-dance') 
        | (df['track_genre'] == 'detroit-techno') | (df['track_genre'] == 'deep-house')| (df['track_genre'] == 'dancehall')
        | (df['track_genre'] == 'trance') | (df['track_genre'] == 'techno')| (df['track_genre'] == 'disco') 
        | (df['track_genre'] == 'dance') | (df['track_genre'] == 'club')| (df['track_genre'] == 'chicago-house')
        | (df['track_genre'] == 'idm') | (df['track_genre'] == 'house')| (df['track_genre'] == 'edm')
        | (df['track_genre'] == 'electronic') | (df['track_genre'] == 'electro')
        , 'genre2'] = 'Dance'
df2.loc[(df['track_genre'] == 'world-music') | (df['track_genre'] == 'malay') |(df['track_genre'] == 'iranian') 
        | (df['track_genre'] == 'turkish') | (df['track_genre'] == 'tango')| (df['track_genre'] == 'swedish') 
        | (df['track_genre'] == 'spanish') | (df['track_genre'] == 'indian')| (df['track_genre'] == 'british')
        | (df['track_genre'] == 'brazil') | (df['track_genre'] == 'german')| (df['track_genre'] == 'french')
        | (df['track_genre'] == 'forro')
        , 'genre2'] = 'Foreign'
df2.loc[(df['track_genre'] == 'afrobeat') | (df['track_genre'] == 'r-n-b') | (df['track_genre'] == 'trip-hop') 
        | (df['track_genre'] == 'soul') | (df['track_genre'] == 'hip-hop'), 'genre2'] = 'Hip_Hop_R&B'
df2.loc[(df['track_genre'] == 'indie') | (df['track_genre'] == 'indie-pop'), 'genre2'] = 'Indie'
df2.loc[(df['track_genre'] == 'kids') | (df['track_genre'] == 'disney')| (df['track_genre'] == 'children'), 'genre2'] = 'Kids'
df2.loc[(df['track_genre'] == 'power-pop') | (df['track_genre'] == 'pop') |(df['track_genre'] == 'pop-film') 
        | (df['track_genre'] == 'mandopop') | (df['track_genre'] == 'k-pop')| (df['track_genre'] == 'j-pop') 
        | (df['track_genre'] == 'j-idol') | (df['track_genre'] == 'synth-pop')| (df['track_genre'] == 'cantopop')
        , 'genre2'] = 'Pop'

df2.loc[(df['track_genre'] == 'piano') | (df['track_genre'] == 'opera') | (df['track_genre'] == 'classical')
         | (df['track_genre'] == 'ambient'), 'genre2'] = 'Classical'
df2.loc[(df['track_genre'] == 'ska') | (df['track_genre'] == 'reggaeton') | (df['track_genre'] == 'reggae')
         | (df['track_genre'] == 'dub') | (df['track_genre'] == 'dubstep'), 'genre2'] = 'Reggae'
df2.loc[(df['track_genre'] == 'punk-rock') | (df['track_genre'] == 'new-age') |(df['track_genre'] == 'metalcore') 
        | (df['track_genre'] == 'metal') | (df['track_genre'] == 'j-rock')| (df['track_genre'] == 'psych-rock')
        | (df['track_genre'] == 'punk') | (df['track_genre'] == 'rock')| (df['track_genre'] == 'rock-n-roll') 
        | (df['track_genre'] == 'death-metal') | (df['track_genre'] == 'black-metal')| (df['track_genre'] == 'alternative')
        | (df['track_genre'] == 'alt-rock') | (df['track_genre'] == 'groove')| (df['track_genre'] == 'heavy-metal')
        | (df['track_genre'] == 'hardstyle') | (df['track_genre'] == 'hardcore') | (df['track_genre'] == 'grindcore')
        | (df['track_genre'] == 'goth') | (df['track_genre'] == 'funk') | (df['track_genre'] == 'emo') | (df['track_genre'] == 'hard-rock')
        , 'genre2'] = 'Rock'

# Check number of genres
new_genre_count = df2.genre2.value_counts()
new_genre_count
# Out:
# C:\Users\admin\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\admin\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Rock           22000
# Dance          17000
# Foreign        13000
# Pop             9000
# Latin           6000
# Hip_Hop_R&B     5000
# Reggae          5000
# Classical       4000
# Country         4000
# Kids            3000
# Cinema          2000
# Jazz_Blues      2000
# Indie           2000
# Name: genre2, dtype: int64

# %%
df2.head()
# Out:
#                     track_id                 artists           album_name  \
# 1000  4pR4oQJULf7FDB54TleMyH  Limoblaze;Lecrae;Happi  Jireh (My Provider)
# 1001  4Ds4bq6aqOSAp1T7DikOi4                  Criolo       Ainda Há Tempo
# 1002  7nYbKsvhM88mHCmFsAIQVp                  Criolo              Fellini
# 1003  7gVNP7rI9UBZndge0ulKfL                  Criolo         Nó na Orelha
# 1004  1hLvWelTny8vttEEZIXVjw                  Criolo    Espiral de Ilusão
#
#                track_name  popularity  duration_ms  explicit  danceability  \
# 1000  Jireh (My Provider)          64       168000     False         0.443
# 1001       Ainda Há Tempo          44       318360     False         0.580
# 1002              Fellini          42       171989     False         0.805
# 1003             Lion Man          46       205440     False         0.582
# 1004    Espiral de Ilusão          44       220800     False         0.776
#
#       energy  key  ...  speechiness  acousticness  instrumentalness  liveness  \
# 1000   0.778    0  ...       0.2660         0.241          0.000000    0.2150
# 1001   0.800    6  ...       0.3450         0.281          0.000000    0.0708
# 1002   0.746    1  ...       0.1850         0.238          0.000000    0.2150
# 1003   0.660    7  ...       0.0544         0.399          0.000000    0.1270
# 1004   0.314    2  ...       0.0340         0.881          0.000723    0.1390
#
#       valence    tempo  time_signature  track_genre  hit       genre2
# 1000    0.628  128.250               5     afrobeat  1.0  Hip_Hop_R&B
# 1001    0.483   81.303               4     afrobeat  0.0  Hip_Hop_R&B
# 1002    0.717  127.922               4     afrobeat  0.0  Hip_Hop_R&B
# 1003    0.484   83.789               4     afrobeat  0.0  Hip_Hop_R&B
# 1004    0.476  124.055               4     afrobeat  0.0  Hip_Hop_R&B
#
# [5 rows x 22 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96000 entries, 1000 to 113999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          96000 non-null  object
#  1   artists           95999 non-null  object
#  2   album_name        95999 non-null  object
#  3   track_name        95999 non-null  object
#  4   popularity        96000 non-null  int64
#  5   duration_ms       96000 non-null  int64
#  6   explicit          96000 non-null  bool
#  7   danceability      96000 non-null  float64
#  8   energy            96000 non-null  float64
#  9   key               96000 non-null  int64
#  10  loudness          96000 non-null  float64
#  11  mode              96000 non-null  int64
#  12  speechiness       96000 non-null  float64
#  13  acousticness      96000 non-null  float64
#  14  instrumentalness  96000 non-null  float64
#  15  liveness          96000 non-null  float64
#  16  valence           96000 non-null  float64
#  17  tempo             96000 non-null  float64
#  18  time_signature    96000 non-null  int64
#  19  track_genre       96000 non-null  object
#  20  hit               96000 non-null  float64
#  21  genre2            94000 non-null  object
# dtypes: bool(1), float64(10), int64(5), object(6)
# memory usage: 16.2+ MB

# %%
df2 = df2.dropna()

# %%
# dropping old genre
df2.drop(['track_genre'], axis = 1, inplace=True)
df2.head()
# Out:
#                     track_id                 artists           album_name  \
# 1000  4pR4oQJULf7FDB54TleMyH  Limoblaze;Lecrae;Happi  Jireh (My Provider)
# 1001  4Ds4bq6aqOSAp1T7DikOi4                  Criolo       Ainda Há Tempo
# 1002  7nYbKsvhM88mHCmFsAIQVp                  Criolo              Fellini
# 1003  7gVNP7rI9UBZndge0ulKfL                  Criolo         Nó na Orelha
# 1004  1hLvWelTny8vttEEZIXVjw                  Criolo    Espiral de Ilusão
#
#                track_name  popularity  duration_ms  explicit  danceability  \
# 1000  Jireh (My Provider)          64       168000     False         0.443
# 1001       Ainda Há Tempo          44       318360     False         0.580
# 1002              Fellini          42       171989     False         0.805
# 1003             Lion Man          46       205440     False         0.582
# 1004    Espiral de Ilusão          44       220800     False         0.776
#
#       energy  key  ...  mode  speechiness  acousticness  instrumentalness  \
# 1000   0.778    0  ...     0       0.2660         0.241          0.000000
# 1001   0.800    6  ...     1       0.3450         0.281          0.000000
# 1002   0.746    1  ...     0       0.1850         0.238          0.000000
# 1003   0.660    7  ...     0       0.0544         0.399          0.000000
# 1004   0.314    2  ...     1       0.0340         0.881          0.000723
#
#       liveness  valence    tempo  time_signature  hit       genre2
# 1000    0.2150    0.628  128.250               5  1.0  Hip_Hop_R&B
# 1001    0.0708    0.483   81.303               4  0.0  Hip_Hop_R&B
# 1002    0.2150    0.717  127.922               4  0.0  Hip_Hop_R&B
# 1003    0.1270    0.484   83.789               4  0.0  Hip_Hop_R&B
# 1004    0.1390    0.476  124.055               4  0.0  Hip_Hop_R&B
#
# [5 rows x 21 columns]

# %%
# rename genre2 to genre
df2.rename(columns = {'genre2': 'genre'}, inplace = True)
df2.head()
# Out:
#                     track_id                 artists           album_name  \
# 1000  4pR4oQJULf7FDB54TleMyH  Limoblaze;Lecrae;Happi  Jireh (My Provider)
# 1001  4Ds4bq6aqOSAp1T7DikOi4                  Criolo       Ainda Há Tempo
# 1002  7nYbKsvhM88mHCmFsAIQVp                  Criolo              Fellini
# 1003  7gVNP7rI9UBZndge0ulKfL                  Criolo         Nó na Orelha
# 1004  1hLvWelTny8vttEEZIXVjw                  Criolo    Espiral de Ilusão
#
#                track_name  popularity  duration_ms  explicit  danceability  \
# 1000  Jireh (My Provider)          64       168000     False         0.443
# 1001       Ainda Há Tempo          44       318360     False         0.580
# 1002              Fellini          42       171989     False         0.805
# 1003             Lion Man          46       205440     False         0.582
# 1004    Espiral de Ilusão          44       220800     False         0.776
#
#       energy  key  ...  mode  speechiness  acousticness  instrumentalness  \
# 1000   0.778    0  ...     0       0.2660         0.241          0.000000
# 1001   0.800    6  ...     1       0.3450         0.281          0.000000
# 1002   0.746    1  ...     0       0.1850         0.238          0.000000
# 1003   0.660    7  ...     0       0.0544         0.399          0.000000
# 1004   0.314    2  ...     1       0.0340         0.881          0.000723
#
#       liveness  valence    tempo  time_signature  hit        genre
# 1000    0.2150    0.628  128.250               5  1.0  Hip_Hop_R&B
# 1001    0.0708    0.483   81.303               4  0.0  Hip_Hop_R&B
# 1002    0.2150    0.717  127.922               4  0.0  Hip_Hop_R&B
# 1003    0.1270    0.484   83.789               4  0.0  Hip_Hop_R&B
# 1004    0.1390    0.476  124.055               4  0.0  Hip_Hop_R&B
#
# [5 rows x 21 columns]

# %%
# Creates dataframe with artists, album_name, track_name, track_id, duration_ms, time_signature, key, mode, and popularity as trackinfo table indicated in ERD
track_df = df2[['artists', 'album_name', 'track_name', 'track_id', 'duration_ms', 'time_signature', 'key', 'mode', 'popularity']].copy()
track_df.head()
# Out:
#                      artists           album_name           track_name  \
# 1000  Limoblaze;Lecrae;Happi  Jireh (My Provider)  Jireh (My Provider)
# 1001                  Criolo       Ainda Há Tempo       Ainda Há Tempo
# 1002                  Criolo              Fellini              Fellini
# 1003                  Criolo         Nó na Orelha             Lion Man
# 1004                  Criolo    Espiral de Ilusão    Espiral de Ilusão
#
#                     track_id  duration_ms  time_signature  key  mode  \
# 1000  4pR4oQJULf7FDB54TleMyH       168000               5    0     0
# 1001  4Ds4bq6aqOSAp1T7DikOi4       318360               4    6     1
# 1002  7nYbKsvhM88mHCmFsAIQVp       171989               4    1     0
# 1003  7gVNP7rI9UBZndge0ulKfL       205440               4    7     0
# 1004  1hLvWelTny8vttEEZIXVjw       220800               4    2     1
#
#       popularity
# 1000          64
# 1001          44
# 1002          42
# 1003          46
# 1004          44

# %%
# Drops artists, album_name, track_name, duration_ms, time_signature,key, mode, and popularity 
df2.drop(['artists', 'track_name', 'duration_ms', 'time_signature', 'key', 'mode', 'popularity'], axis = 1, inplace=True)
df2.head()
# Out:
#                     track_id           album_name  explicit  danceability  \
# 1000  4pR4oQJULf7FDB54TleMyH  Jireh (My Provider)     False         0.443
# 1001  4Ds4bq6aqOSAp1T7DikOi4       Ainda Há Tempo     False         0.580
# 1002  7nYbKsvhM88mHCmFsAIQVp              Fellini     False         0.805
# 1003  7gVNP7rI9UBZndge0ulKfL         Nó na Orelha     False         0.582
# 1004  1hLvWelTny8vttEEZIXVjw    Espiral de Ilusão     False         0.776
#
#       energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 1000   0.778    -7.564       0.2660         0.241          0.000000    0.2150
# 1001   0.800    -7.528       0.3450         0.281          0.000000    0.0708
# 1002   0.746    -5.211       0.1850         0.238          0.000000    0.2150
# 1003   0.660    -4.988       0.0544         0.399          0.000000    0.1270
# 1004   0.314    -9.513       0.0340         0.881          0.000723    0.1390
#
#       valence    tempo  hit        genre
# 1000    0.628  128.250  1.0  Hip_Hop_R&B
# 1001    0.483   81.303  0.0  Hip_Hop_R&B
# 1002    0.717  127.922  0.0  Hip_Hop_R&B
# 1003    0.484   83.789  0.0  Hip_Hop_R&B
# 1004    0.476  124.055  0.0  Hip_Hop_R&B

# %%
# Create sqlalchemy
from sqlalchemy import create_engine
engine = create_engine(f"sqlite:///spotify.sqlite")

# %%
with engine.connect() as conn:
    df2.to_sql('songs', conn, index=False, if_exists='replace')
    track_df.to_sql('trackinfo', conn, index=False, if_exists='replace')
